# %%
import numpy as np
a = np.load("eye2hand_cam1/img_4/pose.npy")
a
# Out:
# array([[ 0.21304522, -0.35256756,  0.31484731,  0.23083826, -0.19515549,
#         -1.1749277 ],
#        [ 0.27724639, -0.37778298,  0.29491875,  0.4877893 , -0.22965798,
#         -1.24218431],
#        [ 0.2283381 , -0.30740238,  0.26484385,  0.42521193, -0.09663074,
#         -1.07768886],
#        [ 0.13489803, -0.25532036,  0.23309938,  0.26095412, -0.14758702,
#         -1.22788605],
#        [ 0.11910763, -0.292134  ,  0.20843841,  0.35855404, -0.16893819,
#         -1.0237229 ],
#        [ 0.25190207, -0.17566635,  0.17355744,  0.46906494, -0.14047123,
#         -0.83423937],
#        [ 0.31361813, -0.24982829,  0.17041594,  0.13036528, -0.20110805,
#         -0.89122756],
#        [ 0.34750279, -0.39670978,  0.14486045,  0.26990364, -0.18055143,
#         -0.75116121],
#        [ 0.36975205, -0.42548882,  0.15004201,  0.41306411, -0.16627679,
#         -0.55794195],
#        [ 0.29202229, -0.57812219,  0.18378604, -0.03179525,  0.13798088,
#         -0.77679829],
# ...

# %%
np.load("rvecs.npy")
# Out:
# array([[[-0.05549889],
#         [ 0.4829802 ],
#         [ 1.73603546]],
#
#        [[-0.59157533],
#         [ 0.43387034],
#         [ 1.40945628]],
#
#        [[-0.73392065],
#         [ 0.54339496],
#         [ 1.56542863]],
#
#        [[-0.18419875],
#         [ 0.38369773],
#         [ 1.65130322]],
#
#        [[ 0.0307014 ],
#         [ 0.42294136],
#         [ 1.47663122]],
#
#        [[ 0.05844814],
#         [ 0.04560192],
#         [ 1.69026374]],
#
#        [[ 0.02271766],
#         [ 0.40648732],
#         [ 1.58514826]],
#
#        [[-0.40854873],
#         [ 0.82886546],
#         [ 1.41017581]],
#
#        [[ 0.24004179],
#         [ 0.2008361 ],
#         [ 1.57656453]],
#
#        [[-0.67949452],
#         [ 0.58547182],
#         [ 1.78365469]],
#
#        [[-0.85392686],
#         [ 0.60656146],
#         [ 2.03108799]],
#
#        [[ 0.15316581],
#         [ 0.28924439],
#         [ 1.82666382]],
#
#        [[-0.64761145],
#         [ 0.46336351],
# ...
